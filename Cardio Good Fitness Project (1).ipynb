# %% [markdown]
# # Cardio Good Fitness Dataset
#
# ### Data Features:
#
# **Product**: model number of the treadmill
#
# **Age**: in number of years, of the customer
#
# **Gender**: of the customer
#
# **Education** : in number of years, of the customer
#
# **Marital Status**: of the customer
#
# **Usage**: Average number of times the customer uses the treadmill every week
#
# **Fitness**: Self rated fitness score of the customer (1-very unfit, 5-very fit)
#
# **Income**: in dollars, of the customer
#
# **Miles**: expected to run

# %% [markdown]
# ### Import the libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(color_codes=True)
# %matplotlib inline

# %% [markdown]
# ### Get the dataset. Check info and shape. Display first and last 5 rows.

# %%
cardio = pd.read_csv('CardioGoodFitness.csv')
# Imports the dataset

# %%
cardio.info()
# Shows the data type for each of the variable, how many data types, and number of values in each variable
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %%
cardio.shape
# shape of the data in terms of rows and columns
# Out:
# (180, 9)

# %%
cardio.head()
# shows the first 5 rows of the dataset
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   TM195   18    Male         14        Single      3        4   29562    112
# 1   TM195   19    Male         15        Single      2        3   31836     75
# 2   TM195   19  Female         14     Partnered      4        3   30699     66
# 3   TM195   19    Male         12        Single      3        3   32973     85
# 4   TM195   20    Male         13     Partnered      4        2   35247     47

# %%
cardio.tail()
# shows the last 5 rows of the dataset
# Out:
#     Product  Age Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 175   TM798   40   Male         21        Single      6        5   83416
# 176   TM798   42   Male         18        Single      5        4   89641
# 177   TM798   45   Male         16        Single      5        5   90886
# 178   TM798   47   Male         18     Partnered      4        5  104581
# 179   TM798   48   Male         18     Partnered      4        5   95508
#
#      Miles
# 175    200
# 176    200
# 177    160
# 178    120
# 179    180

# %% [markdown]
# ### Check for missing values

# %%
pd.DataFrame({'value' : cardio['Product'], 'Missing?' : cardio['Product'].isnull()}) 
#checks for missing values in the Product column
# Out:
#      value  Missing?
# 0    TM195     False
# 1    TM195     False
# 2    TM195     False
# 3    TM195     False
# 4    TM195     False
# ..     ...       ...
# 175  TM798     False
# 176  TM798     False
# 177  TM798     False
# 178  TM798     False
# 179  TM798     False
#
# [180 rows x 2 columns]

# %%
pd.DataFrame({'value' : cardio['Education'], 'Missing?' : cardio['Education'].isnull()}) 
#Checks for missing values in the Education column
# Out:
#      value  Missing?
# 0       14     False
# 1       15     False
# 2       14     False
# 3       12     False
# 4       13     False
# ..     ...       ...
# 175     21     False
# 176     18     False
# 177     16     False
# 178     18     False
# 179     18     False
#
# [180 rows x 2 columns]

# %%
pd.DataFrame( cardio.isnull().sum(), columns= ['Number of missing values'])
#no missing values in any of the variables
# Out:
#                Number of missing values
# Product                               0
# Age                                   0
# Gender                                0
# Education                             0
# MaritalStatus                         0
# Usage                                 0
# Fitness                               0
# Income                                0
# Miles                                 0

# %% [markdown]
# ### EDA Descriptive Statistics

# %% [markdown]
# ### Mean

# %%
print("cardio:",cardio.mean())
# shows the average values in the data
# Out:
# cardio: Age             28.788889
# Education       15.572222
# Usage            3.455556
# Fitness          3.311111
# Income       53719.577778
# Miles          103.194444
# dtype: float64

# %% [markdown]
# ### Mode

# %%
print(cardio['Age'].mode())
# most frequent age
# Out:
# 0    25
# dtype: int64

# %%
print(cardio['Usage'].mode())
# most frequent usage number
# Out:
# 0    3
# dtype: int64

# %%
print(cardio['Miles'].mode())
# most frequent number of miles
# Out:
# 0    85
# dtype: int64

# %% [markdown]
# ### Median

# %%
print("cardio:",cardio.median())
# Out:
# cardio: Age             26.0
# Education       16.0
# Usage            3.0
# Fitness          3.0
# Income       50596.5
# Miles           94.0
# dtype: float64

# %%
print("Cardio_quantile(25%):",cardio.quantile(q=0.25))
# Prints the data in Q1, the first 25% of the data are below these values
# Out:
# Cardio_quantile(25%): Age             24.00
# Education       14.00
# Usage            3.00
# Fitness          3.00
# Income       44058.75
# Miles           66.00
# Name: 0.25, dtype: float64

# %%
print("Cardio_quantile(50%):",cardio.quantile(q=0.50))
# Prints the data in Q2, 50% of the data lies below these values
# Out:
# Cardio_quantile(50%): Age             26.0
# Education       16.0
# Usage            3.0
# Fitness          3.0
# Income       50596.5
# Miles           94.0
# Name: 0.5, dtype: float64

# %%
print("Cardio_quantile(75%):",cardio.quantile(q=0.75))
# Prints the data in Q3, 75% of the data lies below these values
# Out:
# Cardio_quantile(75%): Age             33.00
# Education       16.00
# Usage            4.00
# Fitness          4.00
# Income       58668.00
# Miles          114.75
# Name: 0.75, dtype: float64

# %% [markdown]
# ### Univariate Analysis

# %%
sns.displot(cardio['Gender'],color='rosybrown');

# %%
cardio['Gender'].value_counts()
# Out:
# Male      104
# Female     76
# Name: Gender, dtype: int64

# %%
sns.displot(cardio['MaritalStatus'],color='darkgoldenrod');

# %%
cardio['MaritalStatus'].value_counts()
# Out:
# Partnered    107
# Single        73
# Name: MaritalStatus, dtype: int64

# %%
cardio['Education'].value_counts()
# Out:
# 16    85
# 14    55
# 18    23
# 13     5
# 15     5
# 12     3
# 21     3
# 20     1
# Name: Education, dtype: int64

# %%
sns.distplot(cardio['Age'],color='darkred');
#Majorit of people are between the age of 20 to 40
# Out:
# C:\Users\revat\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.boxplot(cardio['Age'],color='darkred');
# The median age is 26 with outliers past 46
# Out:
# C:\Users\revat\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.distplot(cardio['Education'],color='chocolate');
# Majority of people have 14-18 years of education
# Out:
# C:\Users\revat\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.boxplot(cardio['Education'],color='chocolate');
# There are two outlier points, those who have more than 20+ years of education
# Out:
# C:\Users\revat\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.distplot(cardio['Usage'],color='gold');
# Majority of people use the treadmill between 2-5 times per week
# Out:
# C:\Users\revat\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.boxplot(cardio['Usage'],color='gold');
#There are a couple outliers, those who use the treadmill more than 6 times per week
# Out:
# C:\Users\revat\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.distplot(cardio['Fitness'],color='green')
# Majority of people rate themselves between 2-5 on the fitness level
# Out:
# C:\Users\revat\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Fitness', ylabel='Density'>

# %%
sns.boxplot(cardio['Fitness'],color='green');
#There's an outlier, a person who rated themself a 1 on the fitness scale
# Out:
# C:\Users\revat\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.distplot(cardio['Income'],color='deepskyblue');
#Most people have an income between 30 000 and 75 000
# Out:
# C:\Users\revat\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.boxplot(cardio['Income'],color='deepskyblue');
#The median income is around 50 000
# Out:
# C:\Users\revat\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.distplot(cardio['Miles'],color='indigo');
#Majority of people run between 50 to 200 miles per week
# Out:
# C:\Users\revat\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.boxplot(cardio['Miles'],color='indigo');
## Most users clock in between 50 to 200 miles per week with a median of 94 miles
# Out:
# C:\Users\revat\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.displot(cardio['Product'],color='teal');
#TM195 seems to be the most popular choice followed by TM498 and least popular would be TM798

# %% [markdown]
# ### Multivariate Analysis

# %%
sns.jointplot(cardio['Age'],cardio['Usage']);
# Out:
# C:\Users\revat\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.jointplot(cardio['Age'],cardio['Usage'],kind="kde");
# Out:
# C:\Users\revat\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ### Observations:
# 20s: people have a healthy amount of usage/can be improved/could use more but reflective of the expectations
# and goals of that age group
# Usage peaks close to 30 and then declines from there

# %%
sns.swarmplot(cardio['Gender'],cardio['Usage']);
# Out:
# C:\Users\revat\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\revat\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 23.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\revat\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 10.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ### Observations:
# Starting at a usage level of 4, there are more males using the treadmill
#
# At a usage level of 3, there's an equal amount of male and female users
#
# At a usage level of 2, there's more females than males

# %%
sns.scatterplot(cardio['Education'], cardio['Income'], hue=cardio['Product'], palette='Set2');
# Out:
# C:\Users\revat\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ### Observations:
#
# The higher the education, the higher the income
#
# Starting at 16 years of education, there is a visible shift of purchase from TM195 and TM498 to TM798 --> higher income

# %%
sns.swarmplot(cardio['MaritalStatus'],cardio['Usage']);
# In general, those who use the treadmill more are of the partnered status
# Out:
# C:\Users\revat\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\revat\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 5.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\revat\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 17.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
sns.countplot(y="Product",hue="Gender",data=cardio);

# %% [markdown]
# ### Observations:
# Both gender use the TM195 equally
#
# TM498 is also relatively close to equal
#
# TM798 had the largest disparity with way more male users than female-improvement could be made
# to advertise/market the TM798 to female users

# %%
sns.boxplot(cardio['Age'],cardio['Product']);
# Out:
# C:\Users\revat\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ### Observations:
# Half the TM195 users are in the age range of 22 to 33
#
# Half the TM498 users are in the age range of 23 to 34
#
# Half the TM798 users are in the age range of 25 to 30, this product can be marketed better to have a wider range of customers

# %%
sns.swarmplot(cardio['Product'],cardio['Fitness']);
# Out:
# C:\Users\revat\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\revat\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 46.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\revat\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 36.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\revat\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 30.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
# ...

# %% [markdown]
# ### Observations:
# The TM195 and TM498 have users from a fitness level of 1 to 5, most users are at a 2 or a 3
#
# The TM798 users rate themselves at a higher level, starting at 3

# %%
sns.countplot(y="Product",hue="MaritalStatus",data=cardio);

# %% [markdown]
# ### Observations:
# The biggest disparity in users is for the TM195, with more partnered users
#
# This is followed by the TM498 with the least difference for the TM798
#
# The TM195 and TM498 has the potential of more single users with the right marketing
#
# The TM798 could also use some marketing for single users

# %%
sns.boxplot(cardio['Income'],cardio['Product']);
# Out:
# C:\Users\revat\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ### Observations:
# Users with a higher range of income(58 000 to 90 000) use/buy the TM798, more features? luxury appeal?
# more expensive?
#
# Users with a lower income range (38 000 to 52 000) use/buy the TM195 and TM498, can be the ideal product for those who
# simply want functionality

# %%
sns.boxplot(cardio['Usage'],cardio['Product']);
# Out:
# C:\Users\revat\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ### Observations:
# TM798 users have a higher usage than the other ones
#
# TM498 have the least usage

# %%
sns.pairplot(cardio);

# %%
cardio.corr()
# Out:
#                 Age  Education     Usage   Fitness    Income     Miles
# Age        1.000000   0.280496  0.015064  0.061105  0.513414  0.036618
# Education  0.280496   1.000000  0.395155  0.410581  0.625827  0.307284
# Usage      0.015064   0.395155  1.000000  0.668606  0.519537  0.759130
# Fitness    0.061105   0.410581  0.668606  1.000000  0.535005  0.785702
# Income     0.513414   0.625827  0.519537  0.535005  1.000000  0.543473
# Miles      0.036618   0.307284  0.759130  0.785702  0.543473  1.000000

# %%
sns.heatmap(cardio.corr(),annot=True,cmap="coolwarm");

# %% [markdown]
# ### Observations:
# There's a strong correlation between miles and fitness, miles and usage, fitness and usage and education and income

# %% [markdown]
# ## Scatter plots, any additional observations

# %%
sns.scatterplot(cardio['Miles'],cardio['Income'],hue=cardio['Gender'],palette='Set2');
# Out:
# C:\Users\revat\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ### Observations:
#
# There appears to be roughly an equal amount of male and female users with an income range of 30 000 to 70 000
# who run between 45 to 150 miles
#
# There are more male users who run more than a 150 miles
